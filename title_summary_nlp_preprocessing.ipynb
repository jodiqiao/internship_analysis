# %% [markdown]
# ### Indeed.ca Internship Data Pre-processing

# %% [raw]
# git@github.com:jodiqiao/internship_analysis.git

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sept_final_scrape.csv", usecols = ['job_title','company_name','summary'])

# %%
# summary text give insight to what qualifications are needed for what job?
# qualifications different between companies even if job title similar?
# company-specific preference of qualifications?

# %%
import nltk
#nltk.download()

# %%
sentence = df['summary'][0]

# %%
# test
tokens = nltk.word_tokenize(sentence)

# %%
# https://www.digitalocean.com/community/tutorials/how-to-work-with-language-data-in-python-3-using-the-natural-language-toolkit-nltk
# https://blog.algorithmia.com/introduction-natural-language-processing-nlp
# https://www.kaggle.com/itratrahman/nlp-tutorial-using-python

# %%
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# https://stackoverflow.com/questions/29523254/python-remove-stop-words-from-pandas-dataframe
# compare nltk v sklearn stopwords
# Import stopwords with nltk.

# from nltk.corpus import stopwords
# stop = stopwords.words('english')

# %%
# np.array(stop)
# print("Number of stopwords: ", len(stop))

# %%
from sklearn.feature_extraction import text
stop = text.ENGLISH_STOP_WORDS

# %%
np.array(stop)
print("Number of stopwords: ", len(stop))

# i like this one better
# Out:
# Number of stopwords:  318

# %%
# https://pythonhealthcare.org/2018/12/14/101-pre-processing-data-tokenization-stemming-and-removal-of-stop-words/
# tokenization, stemming, and removal of stop words
# i don't think i'm going to do sentiment analysis... but it's interesting
# convert to lower case

df['job_title'] = df['job_title'].str.lower()
df['company_name'] = df['company_name'].str.lower()
df['summary'] = df['summary'].str.lower()

# %%
import string

# %%
df
# Out:
#                                              job_title  \
# 0               summer intern data science engineering
# 1                                       student intern
# 2                                data scientist intern
# 3    data engineer omnia ai co op intern winter mul...
# 4                   data science intern winter toronto
# 5                 data insight specialist co op intern
# 6                                  data analyst intern
# 7                                  intern data science
# 8             instructional writer data science intern
# 9                       op intern photonics networking
# 10                         applied research lab intern
# 11              business support intern data analytics
# 12   analyst strategic operational risk winter inte...
# 13   associate consultant intern data services univ...
# 14                student intern customer data analyst
# 15                    research intern toronto waterloo
# 16             data scientist internship opportunities
# 17                            op intern data analytics
# 18                 analytics data science co op intern
# 19                      brand management summer intern
# 20                                   accountant intern
# 21              summer intern data science engineering
# 22                                      student intern
# 23       intern opportunities students user experience
# 24                      web front end developer intern
# 25   associate managing consultant intern data serv...
# 26                             python developer intern
# 27                              genuine analyst intern
# 28                                    developer intern
# 29                 software developer intern bs summer
# ..                                                 ...
# 946                  developer enterprise architecture
# 947                                 software developer
# 948  enterprise enabling technology solutions devel...
# 949                    embedded test software engineer
# 950  intern analyst total fund management month con...
# 951  automation monitoring support analyst innovati...
# 952  software testing intern stagiaire en test logi...
# 953                               intern administrator
# 954  software developer intern développeur logiciel...
# 955                  intern analyst digital innovation
# 956                        administrator unpaid intern
# 957                                software tester sam
# 958                    op intern blue planet analytics
# 959           op intern blue planet network management
# 960  software test intern montreal r&d center hikvi...
# 961           software test intern montreal r&d center
# 962                           op intern data analytics
# 963  software test intern montreal r&d center hikvi...
# 964           op intern photonic systems test engineer
# 965           intern ecommerce java software developer
# 966                           op intern data analytics
# 967  user interface ui design intern stagiaire en c...
# 968                                software tester sam
# 969                           op intern data analytics
# 970                                    tester qa month
# 971  user interface ui design intern stagiaire en c...
# 972                                software tester sam
# 973                           op intern data analytics
# 974                                    tester qa month
# 975           intern ecommerce java software developer
#
#                        company_name  \
# 0                  hsbc bank canada
# 1                          skyworks
# 2                            geotab
# 3                          deloitte
# 4                            intact
# 5                    general motors
# 6                 upfeat media inc.
# 7                   rs energy group
# 8                            geotab
# 9                             ciena
# 10              ch four biogas inc.
# 11                           geotab
# 12                         deloitte
# 13                       mastercard
# 14                        celestica
# 15                           google
# 16               nestlé canada inc.
# 17                            ciena
# 18                          td bank
# 19               procter and gamble
# 20                rdm disposal inc.
# 21                 hsbc bank canada
# 22                         skyworks
# 23                        microsoft
# 24                           geotab
# 25                       mastercard
# 26                           geotab
# 27                         autodesk
# 28                           geotab
# 29                           google
# ..                              ...
# 946                         td bank
# 947       nanalysis scientific corp
# 948                         td bank
# 949                          garmin
# 950  ontario teachers' pension plan
# 951                         td bank
# 952                          nuance
# 953       atira development society
# 954                          nuance
# 955                 psp investments
# 956     openconcept consulting inc.
# 957                           nokia
# 958                           ciena
# 959                           ciena
# 960              hikvision usa inc.
# 961           hikvision canada inc.
# 962                           ciena
# 963                       hikvision
# 964                           ciena
# 965                             sap
# 966                           ciena
# 967                          nuance
# 968                           nokia
# 969                           ciena
# 970                         td bank
# 971                          nuance
# 972                           nokia
# 973                           ciena
# 974                         td bank
# 975                             sap
#
#                                                summary
# 0    building changing predictive analytical soluti...
# 1    strong data analysis skill support pes custome...
# 2    data scientist intern work alongside team fell...
# 3    fascinated data structures data models data pa...
# 4    currently looking interns data lab r&d departm...
# 5    data insight specialist assist warranty field ...
# 6    looking data analyst intern join rapidly expan...
# 7    analyze interpret heterogeneous data troublesh...
# 8    geotab seeking intern immediately contribute o...
# 9    autonomous photonic networks team responsible ...
# 10   perform sample analysis collect data currently...
# 11   geotab actively seeking business support inter...
# 12   advisory service line helps organizations tran...
# 13   associate consultant intern data services univ...
# 14   product data management global business servic...
# 15   creating experiments prototyping implementatio...
# 16   data scientist intern explore data answering q...
# 17   data modeling data structures algorithms plus ...
# 18   office chief data officer experience data mana...
# 19   additionally use historical data intern big da...
# 20   compile data compute charges prepare invoices ...
# 21   building changing predictive analytical soluti...
# 22   strong data analysis skill support pes custome...
# 23   knowledge methods gathering analyzing ux resea...
# 24   successful role individual passionate developm...
# 25   experience using data analysis querying tools ...
# 26   work closely data engineering team develop dat...
# 27   analyze piracy trends usage data summarize dat...
# 28   receive detailed data metrics millions vehicle...
# 29   experience data structures algorithms completi...
# ..                                                 ...
# 946  tell story unnoticed explain winning candidate...
# 947  nanalysis global supplier portable nuclear mag...
# 948  tell story unnoticed explain winning candidate...
# 949  embedded test software engineer cochrane ab co...
# 950  opportunity january april total fund managemen...
# 951  td description tell story unnoticed explain wi...
# 952  company overview présentation l entreprise che...
# 953  exciting opportunity exists intern sysadmin it...
# 954  company overview présentation l entreprise che...
# 955  intern analyst digital innovation ll expertise...
# 956  scripting languages including bash php ruby py...
# 957  software tester sam summer op network manageme...
# 958  work team build leading edge network managemen...
# 959  work team developers build leading edge client...
# 960  working team solution specialists project mana...
# 961  working team solution specialists project mana...
# 962  aider l ingénieur e principal e en analyse don...
# 963  working team solution specialists project mana...
# 964  l équipe tests et mesures est responsable test...
# 965  collaborating developers testers team members ...
# 966  aider l ingénieur e principal e en analyse don...
# 967  intern help designers create user experiences ...
# 968  engineering computer science student registere...
# 969  help senior engineers code analytics algorithm...
# 970  td testing quality assurance qa covers special...
# 971  intern help designers create user welcomes int...
# 972  software tester sam summer op network manageme...
# 973  aider l ingénieur e principal e en analyse don...
# 974  explain winning td crave meaningful work embra...
# 975  collaborating developers testers team intern p...
#
# [976 rows x 3 columns]

# %%
# tokenize, remove punctuation, remove stopwords

def pre_process(row):
    data_in_row = row['job_title']
    tokens = nltk.word_tokenize(data_in_row) # is a list of tokens
    #tokens = nltk.word_tokenize(row)
    # taken only words (not punctuation)
    no_punc_no_stop = []
    for i in range(len(tokens)):
        if "/" in tokens[i]:
            # https://stackoverflow.com/questions/9797357/dividing-a-string-at-various-punctuation-marks-using-split
            temp = tokens[i].replace('/',' ').replace('-',' ').split() # this split up web/front, coop/-intern; remove "/","-" keep both wrds
            for a in temp:
                if tokens[i] not in stop:
                    no_punc_no_stop.append(a)
        if tokens[i].isalpha() and tokens[i] != "r" and tokens[i] != "d" and tokens[i] not in stop: # capture text that isn't 'r' or '&' or 'd'
            no_punc_no_stop.append(tokens[i])
        elif tokens[i].isalpha() and tokens[i] == "r": # idk what other words could become just an r
            if tokens[i+1] == "&" and tokens[i+2] == "d": # r & d
                no_punc_no_stop.append("r&d")
                i += 2
            else:
                continue
        
    return " ".join(no_punc_no_stop)

# %%
# speciali note: run summary before job_title.. not too sure why but the output changes if you run job_title first

# df['job_title'] = df.apply(pre_process, axis=1)
# df['summary'] = df.apply(pre_process, axis=1)

# %%
df.to_csv('sept_final_preprocessed.csv') # save preprocessed data for now

# %%
# test stemming
# from nltk.stem import PorterStemmer
# stemming = PorterStemmer()
# b = df['summary'][957]
# Using a Python list comprehension method to apply to all words in m
# print ([stemming.stem(word) for word in b])
# output :
# ['softwar', 'tester', 'sam', 'summer', 'op', 'network', 'manag', 'busi',
# 'unit', 'nokia', 'ip', 'divis', 'recruit', 'highli', 'motiv', 'softwar', 'tester']
# no stemming, this is not great
