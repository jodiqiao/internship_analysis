# %% [markdown]
# ### Indeed.ca Internship Company Name Wordcloud

# %% [raw]
# #### Git push to git@github.com:jodiqiao/internship_analysis.git

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #includes seaborn and wordcloud

# %%
df = pd.read_csv("sept_final_scrape.csv",usecols = ['job_title','company_name','location','summary','salary'])

# %%
df.head()
# Out:
#                                            job_title      company_name  \
# 0          Summer Intern, Data Science & Engineering  HSBC Bank Canada
# 1                                     Student Intern          Skyworks
# 2                              Data Scientist Intern            Geotab
# 3  Data Engineer, Omnia AI - Co-op/Intern Winter ...          Deloitte
# 4        Data Science Intern - Winter 2020 (Toronto)            Intact
#
#        location                                            summary  \
# 0   Toronto, ON  This could be building and changing predictive...
# 1    Ottawa, ON  Has strong data analysis skill. Support PEs wi...
# 2  Oakville, ON  As a Data Scientist Intern, you will work alon...
# 3   Toronto, ON  Fascinated with data structures, data models a...
# 4   Toronto, ON  We are currently looking for interns for our D...
#
#           salary
# 0  Nothing_found
# 1  Nothing_found
# 2  Nothing_found
# 3  Nothing_found
# 4  Nothing_found

# %%
comp_series = pd.value_counts(df['company_name'].values, sort=False)
comp_df = pd.Series.to_frame(comp_series)
comp_df.columns = ['count']
comp_df['company'] = list(comp_df.index)
comp_df = comp_df.sort_values(by=['count'], ascending=False)
comp_df.plot.bar(x='company', y='count', rot=90, legend=False, figsize=(40,10), sort_columns=True, title="number of job postings by company name")
comp_df = comp_df.reset_index(drop=True)
comp_df.head()
# Out:
#    count                         company
# 0     99                         TD Bank
# 1     42                             SAP
# 2     41                             IBM
# 3     37                           Ciena
# 4     35  Ontario Teachers' Pension Plan

# %%
# make a wordcloud for job_title?
# https://www.datacamp.com/community/tutorials/wordcloud-python

# %%
from PIL import Image #python imaging library
from os import path
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# to string
# comp_only = df['company_name'].to_string().strip() #bad string but wordcloud reads it..

string = ""
for i in range(0,len(df['company_name'])):
               string = string + df['company_name'][i] + "\n"

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", colormap="Accent").generate(string)
plt.figure()

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
#plt.show()
plt.annotate('Source: Indeed.ca, 2019',xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')
plt.savefig('company_wordcloud.png')
